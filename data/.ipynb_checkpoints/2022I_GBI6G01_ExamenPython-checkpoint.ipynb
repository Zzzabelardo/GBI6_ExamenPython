# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/d/de/Logotipo_Ikiam.png/800px-Logotipo_Ikiam.png" width=300 height=240 />
#
# # <center> EXAMEN PARCIAL PYTHON
#
#
# ## GBI6-2021II: BIOINFORMÁTICA
#
# **Roa Portalanza, Luis Carlos**
#
# **05-08-2022**
#
# ## Datos Personales
#
# Luis Carlos Roa Portalanza
#
# Carrera de biotecnología
#
# 21 años
#
# C.I: 1501126674
#
# ## Características del Ordenador
#
# |Característica |Detalle |
# |---------------|--------|
# |Nombre del dispositivo |LAB-C-E1 |
# |Nombre completo del dispositivo |LAB-C-E1.ikiam.edu.ec |
# |Procesador |Intel(R) Core(TM) i7-4770 CPU @ 3.40GHz   3.40 GHz |
# |RAM instalada |8.00 GB |
# |Identificador de dispositivo |6C607C7C-0EB0-48D3-8E71-BB470A5D9F10 |
# |Id. del producto |00330-80000-00000-AA861 |
# |Tipo de sistema |Sistema operativo de 64 bits, procesador basado en x64 |
# |Lápiz y entrada táctil |La entrada táctil o manuscrita no está disponible para esta pantalla |

# %% [markdown]
# <font color='red'>Color de texto</font>

# %% [markdown]
# ### REQUERIMIENTOS PARA EL EXAMEN
#
# Utilice de preferencia ```Jupyter``` de Anaconda, dado que tienen que hacer un control de cambios en cada pregunta.
#
# Para este examen se requiere dos documentos:
#
# 1. Archivo ```miningscience.py``` donde tendrá dos funciones:
#
# 2. Archivo ```2022I_GBI6_ExamenPython``` donde se llamará las funciones y se obtendrá resultados.

# %% [markdown]
# ## Ejercicio 0 [0.5 puntos]
# Realice cambios al cuaderno de jupyter:
# - Agregue el logo de la Universidad
# - Coloque sus datos personales
# - Escriba una **tabla** con las características de su computador

# %% [markdown]
# ## Ejercicio 1 [2 puntos]
# Cree el archivo ```miningscience.py``` con las siguientes dos funciones:
#
# i. ```download_pubmed```: para descargar la data de PubMed utilizando el **ENTREZ** de Biopython. El parámetro de entrada para la función es el ```keyword```.
#
# ii. ```science_plots```: la función debe
#
# - utilizar como argumento de entrada la data descargada por ```download_pubmed```
# - ordenar los conteos de autores por país en orden ascedente y
# - seleccionar los cinco más abundantes. Con esta selección debe graficar un ```pie_plot```. Como guía para el conteo por países puede usar el ejemplo de [MapOfScience](https://github.com/CSB-book/CSB/blob/master/regex/solutions/MapOfScience_solution.ipynb).
#
# iii *Cree un docstring para cada función.*
#
# Luego de crear las funciones, cargue el módulo ```miningscience``` como ```msc``` e **imprima docstring de cada función**.

# %%
# Descarga de librerías

# !pip install biopython
# !pip install reportlab
# !pip install nglview
# Out:
# Requirement already satisfied: biopython in c:\users\aula\anaconda3\lib\site-packages (1.79)
# Requirement already satisfied: numpy in c:\users\aula\anaconda3\lib\site-packages (from biopython) (1.20.3)
# Requirement already satisfied: reportlab in c:\users\aula\anaconda3\lib\site-packages (3.6.11)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\aula\anaconda3\lib\site-packages (from reportlab) (9.2.0)
# Requirement already satisfied: nglview in c:\users\aula\anaconda3\lib\site-packages (3.0.3)
# Requirement already satisfied: jupyterlab-widgets in c:\users\aula\anaconda3\lib\site-packages (from nglview) (1.0.0)
# Requirement already satisfied: ipywidgets>=7 in c:\users\aula\anaconda3\lib\site-packages (from nglview) (7.6.5)
# Requirement already satisfied: numpy in c:\users\aula\anaconda3\lib\site-packages (from nglview) (1.20.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\aula\anaconda3\lib\site-packages (from ipywidgets>=7->nglview) (3.5.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\aula\anaconda3\lib\site-packages (from ipywidgets>=7->nglview) (6.4.1)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\aula\anaconda3\lib\site-packages (from ipywidgets>=7->nglview) (5.1.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\aula\anaconda3\lib\site-packages (from ipywidgets>=7->nglview) (0.2.0)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\aula\anaconda3\lib\site-packages (from ipywidgets>=7->nglview) (7.29.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\aula\anaconda3\lib\site-packages (from ipywidgets>=7->nglview) (5.1.3)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\aula\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7->nglview) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\aula\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7->nglview) (1.4.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\aula\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7->nglview) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\aula\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7->nglview) (6.1.12)
# Requirement already satisfied: setuptools>=18.5 in c:\users\aula\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7->nglview) (58.0.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\aula\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7->nglview) (3.0.20)
# Requirement already satisfied: decorator in c:\users\aula\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7->nglview) (5.1.0)
# Requirement already satisfied: backcall in c:\users\aula\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7->nglview) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\aula\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7->nglview) (0.7.5)
# Requirement already satisfied: colorama in c:\users\aula\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7->nglview) (0.4.4)
# Requirement already satisfied: pygments in c:\users\aula\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7->nglview) (2.10.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\aula\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7->nglview) (0.18.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\aula\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7->nglview) (0.8.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\aula\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7->nglview) (22.2.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\aula\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7->nglview) (4.8.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\aula\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7->nglview) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\aula\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7->nglview) (228)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\aula\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7->nglview) (3.2.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\aula\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7->nglview) (21.2.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\aula\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7->nglview) (1.16.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\aula\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7->nglview) (0.18.0)
# Requirement already satisfied: wcwidth in c:\users\aula\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7->nglview) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\aula\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7->nglview) (6.4.5)
# Requirement already satisfied: nbconvert in c:\users\aula\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7->nglview) (6.1.0)
# Requirement already satisfied: argon2-cffi in c:\users\aula\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7->nglview) (20.1.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\aula\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7->nglview) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\aula\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7->nglview) (0.9.4)
# Requirement already satisfied: jinja2 in c:\users\aula\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7->nglview) (2.11.3)
# Requirement already satisfied: prometheus-client in c:\users\aula\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7->nglview) (0.11.0)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\aula\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7->nglview) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\aula\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7->nglview) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\aula\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7->nglview) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\aula\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7->nglview) (1.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\aula\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7->nglview) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\aula\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7->nglview) (1.4.3)
# Requirement already satisfied: defusedxml in c:\users\aula\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7->nglview) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\aula\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7->nglview) (0.1.2)
# Requirement already satisfied: testpath in c:\users\aula\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7->nglview) (0.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\aula\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7->nglview) (0.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\aula\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7->nglview) (0.5.3)
# Requirement already satisfied: bleach in c:\users\aula\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7->nglview) (4.0.0)
# Requirement already satisfied: nest-asyncio in c:\users\aula\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7->nglview) (1.5.1)
# Requirement already satisfied: async-generator in c:\users\aula\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7->nglview) (1.10)
# Requirement already satisfied: packaging in c:\users\aula\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7->nglview) (21.0)
# Requirement already satisfied: webencodings in c:\users\aula\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7->nglview) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\aula\anaconda3\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7->nglview) (3.0.4)

# %%
# Lectura y visualización

from IPython.core.display import Image
from Bio.Seq import Seq
from Bio.SeqUtils import GC

from reportlab.lib import colors
from reportlab.lib.units import cm
from Bio.Graphics import GenomeDiagram
from Bio import SeqIO
from Bio.SeqFeature import SeqFeature, FeatureLocation

# Filogenia

from Bio import Phylo
from Bio.Phylo.TreeConstruction import DistanceCalculator
from Bio.Phylo.TreeConstruction import DistanceTreeConstructor
from Bio import AlignIO

# Proteómica

from Bio.PDB import *
from Bio.SeqUtils.ProtParam import ProteinAnalysis
from Bio.SeqUtils.ProtParam import ProtParamData
import nglview as nv
import ipywidgets

import warnings
warnings.filterwarnings('ignore')

# %%
def download_pubmed(k): 
    """
    Docstring download_pubmed
    k = Keyword1, palabra clave con la que se realizará la búsqueda
    """
from Bio import Entrez 
import re

Entrez.email = "gualapuro.moises@gmail.com"
handle = Entrez.esearch(db="pubmed", 
                        term="k[Title]",
                        usehistory="y")
record = Entrez.read(handle)
id_list = record["IdList"]
record["Count"]
print (record)
  
webenv = record["WebEnv"]
query_key = record["QueryKey"]
handle = Entrez.efetch(db="pubmed",
                       rettype="medline", 
                       retmode="text", 
                       retstart=0,
retmax=543, webenv=webenv, query_key=query_key)
# Out:
# {'Count': '72077', 'RetMax': '20', 'RetStart': '0', 'QueryKey': '1', 'WebEnv': 'MCID_62ed877b019b503ce9731376', 'IdList': ['35926706', '35924571', '35923696', '35922896', '35922516', '35922487', '35922389', '35922349', '35921926', '35921218', '35920873', '35920395', '35920373', '35919339', '35919270', '35917436', '35916220', '35915786', '35914230', '35913019'], 'TranslationSet': [], 'TranslationStack': [{'Term': 'k[Title]', 'Field': 'Title', 'Count': '72077', 'Explode': 'N'}, 'GROUP'], 'QueryTranslation': 'k[Title]'}

# %%
from Bio import Entrez 
import re
import miningscience_g01 as msc
msc.download_pubmed("catus")
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\aula\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "C:\Users\aula\AppData\Local\Temp/ipykernel_12276/3887438457.py", line 3, in <module>
#     import miningscience_g01 as msc
#
#   File "C:\Users\aula\Desktop\Examen Bioinformatica\GitHub\GBI6_ExamenPython\data\miningscience_g01.py", line 5
#     !pip install biopython
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Ejercicio 2 [2 puntos]
#
#
# Utilice dos veces la función ```download_pubmed``` para:
#
# - Descargar la data, utilizando los keyword de su preferencia.
# - Guardar el archivo descargado en la carpeta ```data```.
#
# Para cada corrida, imprima lo siguiente:
#
# ```python
# 'El número artículos para KEYWORD es: XX' # Que se cargue con inserción de texto o valor que correspondea KEYWORD y XX
# ```

# %%
# Escriba aquí su código para el ejercicio 2

# %% [markdown]
# ## Ejercicio 3 [1.5 puntos]
#
# Utilice dos veces la función ```science_plots``` para:
#
# - Visualizar un pie_plot para cada data descargada en el ejercicio 2.
# - Guardar los pie_plot en la carpeta ```img```

# %%
# Escriba aquí su código para el ejercicio 3

# %% [markdown]
# ## Ejercicio 4 [1 punto]
#
# **Interprete** los resultados de las figuras del **ejercicio 3**

# %% [markdown]
# *Escriba la respuesta del ejercicio 5*
# .
#
#
# .
#
# .

# %% [markdown]
# ## Ejercicio 5 [2 puntos]
#
# Para algún **gen de las enzimas que intervienen en la ruta metabolica de la gluconeogenesis** ([Lista de genes por tipología](https://www.genome.jp/pathway/map00010+C00068)), realice lo siguiente:
#
# 1. Una búsqueda en la página del [NCBI nucleotide](https://www.ncbi.nlm.nih.gov/nucleotide/).
#
# 2. Descargue el ```Accession List``` de su búsqueda y guarde en la carpeta ```data```.
#
# 3. Cargue el ```Accession List``` en este notebook y haga una descarga de las secuencias de los **quince primeros** IDs de la accesión.
#
# 4. Arme un árbol filogenético para los resultados del paso 3.
#
# 5. Guarde su arbol filogénetico en la carpeta ```img```
#
# 5. Interprete el árbol del paso 4.

# %%
# Escriba aquí su código para el ejercicio 6

# %% [markdown]
# **Escriba aquí la interpretación del árbol**

# %% [markdown]
# ## Ejercicio 6 [1 punto]
#
#
# 1. Cree en GitHub un repositorio de nombre ```GBI6_ExamenPython```.
# 2. Cree un archivo ```Readme.md``` que debe tener lo siguiente:
# - Datos personales
# - Características del computador
# - Versión de Python/Anaconda y de cada uno de los módulos/paquetes y utilizados
# - Explicación de la data utilizada
# - Un diagrama de procesos del módulo ```miningscience```
# 3. Asegurarse que su repositorio tiene las carpetas ```data``` e ```img``` con los archivos que ha ido guardando en las preguntas anteriores.
# 4. Realice al menos 1 control de la versión (commits) por cada ejercicio (del 1 al 5), con un mensaje que inicie como:
#
# ```sh
# Carlitos Alimaña ha realizado el ejercicio 1
# ```
# ```sh
# Carlitos Alimaña ha realizado el ejercicio 2
# ```
# ```sh
# ...
# ```
